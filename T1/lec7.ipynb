# %% [markdown]
# # ch-2

# %%
# importing the modules
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data)
plt.show()
# Out:
# C:\Users\LJENG\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# The data to be plotted:
#
# [[48 97 11 87 36 26 31 99 26 98]
#  [77  4  4  6 88  9 95 22 36 95]
#  [71 44 48 31 35 12 92 19 70 12]
#  [29 45 33 81 19 28 12  7 12 95]
#  [99 51 23 43  7 84 89 34 71 11]
#  [16 23 11 37 37 11 42 81 64 51]
#  [96 11 60 85 59 50 71 85 94 20]
#  [ 6 92 31 80 67 94 88 69 80 10]
#  [20 85 60 25 83 80 85 45 13 53]
#  [14 14 47  1 27 34 19  4 33 61]]

# %%
# importing the modules
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data,annot=True)
plt.show()
# Out:
# The data to be plotted:
#
# [[87 16 67 32 75 75  9 81 27 81]
#  [ 3 82 32 35 48 88 72 95 74 59]
#  [79 10 44 88 66 59 45 66 73 15]
#  [81 75 96 73 99 64 92 26 63 83]
#  [41 99  7  4 24  2 34 52  3 65]
#  [92 92 91 94 85 39 86 51 50 23]
#  [71 58 33 95 76 78 58 12 26  6]
#  [ 9 95 70 29 30 11 13 38 89 70]
#  [59 10 76 23 81 80 34 10 70 88]
#  [89 42 94 78 60 15  2 76 21 14]]

# %%
# importing the modules
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data,annot=True,vmin=30,vmax=70)
plt.show()
# Out:
# The data to be plotted:
#
# [[98 44 90 81 93 16 77 24 79 24]
#  [86  4 77 13 51 82 15 88 99 57]
#  [79 93 70 18 99 43 74 96 70 56]
#  [31 58 72 55 56 65 53 58 83 19]
#  [ 2 87 72 21 38 78 90 28 30 16]
#  [68 77 54 36 64 44 99 93 86 92]
#  [85 60 57 78 53 55 40 12 95 45]
#  [46 16 70 32 78 70 18 98 17 68]
#  [48 35  7 57 53 75 78 71 22 59]
#  [24 85 20 23 44 95  3 97 39 53]]

# %%
# importing the modules
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data,cmap="tab20")
plt.show()
# Out:
# The data to be plotted:
#
# [[49 70 21 93 36 91  6 57 75 19]
#  [85  1 18 97 66 58 16 33 47 43]
#  [95 22 85 55 51 85 69  3 53 52]
#  [48  5 45 64 92 63 60 84 11 60]
#  [ 6  6 73  8 18 28 73 91 93 47]
#  [32 11 16 70 60 36 18  8 98 81]
#  [ 9 64 79 23 77  1 31  9 68 89]
#  [ 6 63 40 34  7 40 21 66 37 89]
#  [66 34 87  8 87 30 30 68 77 59]
#  [43 12 85 25 16  6 42 54 49 34]]

# %%
# importing the modules
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data,annot=True,vmin=30,vmax=70,cmap="tab10",linewidths=1,linecolor="black",cbar=False,xticklabels=False,yticklabels=True)
plt.show()
# Out:
# The data to be plotted:
#
# [[22 51 68 30 34 22 67 73 18 39]
#  [73 74 18 16 47 24 22 43 57 45]
#  [86 15 92 15 33 35 56 75 22 93]
#  [35 50 91 40 84 38 84 20 32 68]
#  [40 82 59 22 51 26  2 36 12 26]
#  [82 52 86 64 29 39 35 99 29 40]
#  [62  9 52 91 43 92 97 68 88 30]
#  [66  4 14 67 71 97 46 25 60 15]
#  [76 55 90 17 36 41 28 70 50 40]
#  [64 34 92 14 52 34 34  7 32  4]]

# %%
import pandas as pd
import numpy as np
# create a dataset
df=pd.DataFrame(np.random.random((5,5)),columns=["a","b","c","d","e"])
print(df)
p1=sns.heatmap(df)
plt.show()
# Out:
#           a         b         c         d         e
# 0  0.241271  0.137639  0.322170  0.099252  0.503156
# 1  0.043095  0.661652  0.088947  0.166842  0.645621
# 2  0.315245  0.042326  0.698444  0.506171  0.115939
# 3  0.743607  0.051530  0.001163  0.923649  0.117693
# 4  0.468189  0.142850  0.113584  0.003508  0.399611

# %%
# importing the modules
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,4))
data=np.random.randint(low=1,high=100,size=(3,10))
print("The data to be plotted:\n")
print(data)
sns.heatmap(data,annot=True,vmin=20,vmax=80,cmap="tab20",linewidths=2,linecolor="black",xticklabels=False,yticklabels=True)
plt.show()
# Out:
# The data to be plotted:
#
# [[72 88 76 54 49  8 10 44 66 70]
#  [19 63 38 91 67 95 55 20 90 11]
#  [52 47 80 38 27  1 72 78 48 78]]

# %%
df=pd.read_csv("auto-mpg.csv")
sns.boxplot(y=df['mpg'])
plt.show()

# %%
df=pd.read_csv("auto-mpg.csv")
sns.boxplot(y=df['acceleration'])
plt.show()

# %%
df=sns.load_dataset("tips")
sns.boxplot(x="day",y="total_bill",hue="smoker",data=df)
plt.show()

# %% [markdown]
# # scatter plot

# %%
df=pd.read_csv("auto-mpg.csv")
df["horsepower"]=pd.to_numeric(df["horsepower"],errors="coerce")
df=df.dropna(subset=["horsepower"])
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='horsepower',y='mpg',hue='origin',style='origin',size='weight',palette='Set1')
plt.show()
